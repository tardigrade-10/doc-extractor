# %%
from bs4 import BeautifulSoup

with open("project.html") as fp:
    soup = BeautifulSoup(fp, "html.parser")

# %%
soup.find("a", href = True)["href"]
# Out:
# '../reports/2017/pdfs/119.pdf'

# %%
soup
# Out:
# <div class="container sec" id="reports">
# <div id="counter-div">Showing 256 of 345 projects (89 requested to remain private)</div><br/>
# <div class="pt">
# <a href="../reports/2017/pdfs/119.pdf" target="_blank">Convolutional Neural Network Classification of Functional Shoe Types</a>
# <a href="../reports/2017/posters/119.pdf" target="_blank">(poster)</a>
# <div class="pa">
#       Jaime Deverall, Jiwoo Lee, Miguel Ayala
#     </div>
# <div class="pi">
# <a href="../reports/2017/pdfs/119.pdf" target="_blank">
# <img src="../reports/2017/thumbs/119.png"/>
# </a>
# </div>
# <br/>
# </div>
# <div class="pt">
# <a href="../reports/2017/pdfs/426.pdf" target="_blank">DeepSynth: Synthesizing A Musical Instrument With Video</a>
# <a href="../reports/2017/posters/426.pdf" target="_blank">(poster)</a>
# <div class="pa">
#       Tal Stramer
#     </div>
# <div class="pi">
# <a href="../reports/2017/pdfs/426.pdf" target="_blank">
# <img src="../reports/2017/thumbs/426.png"/>
# </a>
# </div>
# ...

# %%
import numpy as np

np.linspace(35, 40, 30)
# Out:
# array([35.        , 35.17241379, 35.34482759, 35.51724138, 35.68965517,
#        35.86206897, 36.03448276, 36.20689655, 36.37931034, 36.55172414,
#        36.72413793, 36.89655172, 37.06896552, 37.24137931, 37.4137931 ,
#        37.5862069 , 37.75862069, 37.93103448, 38.10344828, 38.27586207,
#        38.44827586, 38.62068966, 38.79310345, 38.96551724, 39.13793103,
#        39.31034483, 39.48275862, 39.65517241, 39.82758621, 40.        ])
